# %% [markdown]
# ## <b>DATA VISUALIZATION WITH MATPLOTLIB AND SEABORN</b>

# %% [markdown]
# #### INSTALL SOFTWARE AND IMPORT LIBRARIES

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 653.6 kB/s eta 0:00:01
#    ------------ --------------------------- 92.2/294.9 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.4 MB/s eta 0:00:00
# ...

# %%
# Matplotlib - Matrix Plotting Library (a data visualization library)
import matplotlib.pyplot as plt

# Seaborn is built on matplotlib and gives us more concise syntax to perform basic matplotlib operations
import seaborn as sns

# This special command ensures that graphics do not generate on a seperate pop-up window
# %matplotlib inline

# %% [markdown]
# #### LINE CHARTS
#
# Line charts are one of the simplest and most widely used data visualization techniques. They are best for displaying continuous data trends over time - stock prices, population growth, temperature changes, etc. They're also good for displaying continuous data trends across different categories - sales performance for several products.

# %% [markdown]
# We'll start by setting a variable and assigning it a list of floats representing some yield of apples over 6 years:

# %%
apple_yields = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %% [markdown]
# We can visualize trends in this data with a line chart using plt.plot()

# %%
# Adding a semi-colon to the end of the statement prevents showing textual output
plt.plot(apple_yields);

# %% [markdown]
# We can customize graphs to make them more informative and readable.

# %% [markdown]
# ##### Customizing the X-Axis
# Because this is a graph showing information over time, it would be useful to label the x-axis with dates.

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
plt.plot(years, apple_yields);

# %% [markdown]
# ##### Axis Labels
# We can show what each axis represents as well.

# %%
plt.plot(years, apple_yields);
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
# Out:
# Text(0, 0.5, 'Yield (tons per hectare)')

# %% [markdown]
# ##### Plotting Multiple Lines
# Plotting multiple lines is great for comparing data visually.

# %%
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908]
plt.plot(years, apple_yields);
plt.plot(years, oranges);
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
# Out:
# Text(0, 0.5, 'Yield (tons per hectare)')

# %% [markdown]
# ##### Chart Title and Legend
# To differentiate the lines, we can add a legend. We can also display a title for our graph.

# %%
plt.plot(years, apple_yields)
plt.plot(years, oranges)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# ##### Line Markers
# We can highlight where exactly each point lies using markers. There are many different styles of markers which can be found in the matplotlib documentation.

# %%
plt.plot(years, apple_yields, marker='o')
plt.plot(years, oranges, marker='x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# ##### Styling Lines and Markers
# There are many arguments for styling lines and markers that can also be found in the documentation. Some include:
# - color or c
# - linestyle or ls
# - linewidth or lw
# - markersize or ms
# - markeredgecolor or mec
# - markeredgewidth or mew
# - markerfacecolor or mfc
# - alpha

# %%
plt.plot(years, apple_yields, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# There is a special fmt argument that allows us to customize line style, marker, and line color.
#
# fmt = '[marker][line][color]'
#
# If no line style is specified, only markers are drawn.

# %%
plt.plot(years, apple_yields, 's-b')
plt.plot(years, oranges, 'or')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# ##### Changing Figure Size

# %%
plt.figure(figsize=(8, 4))

plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hectare)');

# %%
plt.figure(figsize=(2, 2))

plt.plot(years, oranges, 'or')
plt.title('Yield of Oranges (tons per hectare)');

# %% [markdown]
# #### IMPROVING DEFAULT STYLES USING SEABORN
# An easy way to improve style of charts is to use default styles from the Seaborn library. These can be applied globally using the sns.set_style function.

# %%
sns.set_style('whitegrid')

# %%
plt.plot(years, apple_yields, 's-b')
plt.plot(years, oranges, 'or')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years, apple_yields, 's-b')
plt.plot(years, oranges, 'or')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# You can also edit default styles directly by modifying the matplotlib.rcParams dictionary. You can check the documentation for more details.

# %%
import matplotlib

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %% [markdown]
# #### SCATTERPLOTS
# Used to visualize the relationship between 2 variables as points on a 2D grid.

# %%
flowers_df = sns.load_dataset("iris")
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# Lets use a line chart to visualize the relationship between sepal length and width. We'll see how this is not a very effective way of visualizing this information compared to using a scatterplot.

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width);

# %% [markdown]
# Our dataset is not collected in any order (chronological), which makes a line chart useless for this scenario.

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width);

# %% [markdown]
# Notice how the Seaborn function labeled our axes automatically? Matplotlib didnt have this ability, so already we can see how Seaborn improves upon Matplotlib.

# %% [markdown]
# If we analyze this chart, we can count about 3 clusters of points on the graph. We could deduce that each cluster represents a species (flowers of the same species will have similar qualities). We would not have been able to see this relationship in the line graph.

# %% [markdown]
# ##### Adding Hues
# We color the points on the scatterplot according to species using the hue attribute.

# %%
sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species, s=100);

# %% [markdown]
# ##### Customizing Seaborn Figures
# Since Seaborn is built on Matplotlib, we can use Matplotlib functions to modify Seaborn object.

# %%
plt.figure(figsize=(12,6))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species, s=100);

# %% [markdown]
# ##### Plotting Using Pandas Dataframes
# Seaborn has built-in support for pandas dataframes. Instead of passing each column as a series like we did above, you can pass column names and use the data argument to pass the dataframe.

# %%
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length',
                y='sepal_width',
                hue='species',
                s=100,
                data=flowers_df);

# %% [markdown]
# #### HISTOGRAMS

# %% [markdown]
# #### EVERY TOOL FROM THIS SECTION:
#
# - import sys
# - !{sys.executable}
#
# Line charts:
# - plt.plot()
# - plt.xlabel()
# - plt.ylabel()
# - plt.title()
# - plt.legend()
# - fmt
# - style lines and markers
# - plt.figure(figsize=())
# - sns.set_style
# - matplotlib.rcParams
